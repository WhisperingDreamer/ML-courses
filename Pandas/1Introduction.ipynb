# %% [markdown]
# # Series

# %%
import pandas as pd
import numpy as np

# %%
myseries = pd.Series([10, 20, 30])

# %%
print(myseries)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
myseries.dtype
# Out:
# dtype('int64')

# %%
myseries = pd.Series(
    [10, 20, 30],
    index = ['a', 'b', 'c']
)

print(myseries)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
myseries = pd.Series(['Jane', 'John', 'Emily', 'Matt'])

print(myseries[0])
# Out:
# Jane

# %%
myseries = pd.Series([1, 2, 3])
print(myseries.is_unique)
# Out:
# True

# %%
myseries[1] = 3
print(myseries.is_unique)
print(myseries)
# Out:
# False
# 0    1
# 1    3
# 2    3
# dtype: int64

# %% [markdown]
# # Dataframe

# %%
df = pd.DataFrame({'Name': ['Jane', 'John', 'Matt', 'Ashley'], 'Age': [24, 21, 26, 32]})
print(df)
# Out:
#      Name  Age
# 0    Jane   24
# 1    John   21
# 2    Matt   26
# 3  Ashley   32

# %%
print(df.shape)
# Out:
# (4, 2)

# %%
print(df.iloc[1])
# Out:
# Name    John
# Age       21
# Name: 1, dtype: object

# %% [markdown]
# # read_csv

# %%
sales = pd.read_csv('sales.csv')
print(sales.head())
# Out:
#    product_code product_group  stock_qty    cost    price  last_week_sales  \
# 0          4187           PG2        498  420.76   569.91               13
# 1          4195           PG2        473  545.64   712.41               16
# 2          4204           PG2        968  640.42   854.91               22
# 3          4219           PG2        241  869.69  1034.55               14
# 4          4718           PG2       1401   12.54    26.59               50
#
#    last_month_sales
# 0                58
# 1                58
# 2                88
# 3                45
# 4               285

# %%
sales_test = pd.read_csv("sales.csv", usecols=["product_code","product_group","stock_qty"])

print(sales_test.head())
# Out:
#    product_code product_group  stock_qty
# 0          4187           PG2        498
# 1          4195           PG2        473
# 2          4204           PG2        968
# 3          4219           PG2        241
# 4          4718           PG2       1401

# %%
df = pd.DataFrame({
  "Names": ["Jane", "John", "Matt", "Ashley"],
  "Ages": [26, 24, 28, 25],
  "Score": [91.2, 94.1, 89.5, 92.3]
})

print(df)
# Out:
#     Names  Ages  Score
# 0    Jane    26   91.2
# 1    John    24   94.1
# 2    Matt    28   89.5
# 3  Ashley    25   92.3

# %%
arr = np.random.randint(1, 10, size=(3,5))
df = pd.DataFrame(arr, columns=['A', 'B', 'C', 'D', 'E'])
print(df)
# Out:
#    A  B  C  D  E
# 0  4  9  7  6  8
# 1  4  5  2  4  1
# 2  8  7  1  7  5

# %%
sales = pd.read_csv("sales.csv")

# %%
print(sales.shape)
print(sales.size)
print(len(sales))
# Out:
# (1000, 7)
# 7000
# 1000

# %%
print(sales.dtypes)
# Out:
# product_code          int64
# product_group        object
# stock_qty             int64
# cost                float64
# price               float64
# last_week_sales       int64
# last_month_sales      int64
# dtype: object

# %%
print(sales.columns)
# Out:
# Index(['product_code', 'product_group', 'stock_qty', 'cost', 'price',
#        'last_week_sales', 'last_month_sales'],
#       dtype='object')

# %%
print(list(sales.columns))
# Out:
# ['product_code', 'product_group', 'stock_qty', 'cost', 'price', 'last_week_sales', 'last_month_sales']

# %%
sales['stock_qty'] = sales['stock_qty'].astype('float')
print(sales.dtypes)
# Out:
# product_code          int64
# product_group        object
# stock_qty           float64
# cost                float64
# price               float64
# last_week_sales       int64
# last_month_sales      int64
# dtype: object

# %%
sales = sales.astype({
  "stock_qty": "float",
  "last_week_sales": "float"
})

print(sales.dtypes)
# Out:
# product_code          int64
# product_group        object
# stock_qty           float64
# cost                float64
# price               float64
# last_week_sales     float64
# last_month_sales      int64
# dtype: object

# %%
print(sales['product_group'].nunique())
print(sales['product_group'].unique())
# Out:
# 6
# ['PG2' 'PG4' 'PG6' 'PG5' 'PG3' 'PG1']

# %%
print(sales['product_group'].value_counts())
# Out:
# product_group
# PG4    349
# PG5    255
# PG6    243
# PG2     75
# PG3     39
# PG1     39
# Name: count, dtype: int64

# %%
myseries = pd.Series([1, 2, 5, 7, 11, 36])
print(myseries.median())
# Out:
# 6.0

# %%
myseries = pd.Series([1, 4, 6, 6, 6, 11, 11, 24])
print(myseries.mode()[0])
# Out:
# 6

# %%
print(sales.mode())
# Out:
#    product_code product_group  stock_qty   cost  price  last_week_sales  \
# 0        5694.0           PG4      313.0   3.85  10.44             13.0
# 1           NaN           NaN      749.0  12.93    NaN              NaN
#
#    last_month_sales
# 0              48.0
# 1               NaN

# %%
sales = pd.read_csv('sales.csv')
print('Mean:')
print(sales['price'].mean())

print('Median:')
print(sales['price'].median())

print('Mode:')
print(sales['price'].mode()[0])

print('Min:')
print(sales['price'].min())

print('Max:')
print(sales['price'].max())
# Out:
# Mean:
# 67.06351000000001
# Median:
# 23.74
# Mode:
# 10.44
# Min:
# 0.66
# Max:
# 1500.05

# %%
print('Variance:')
print(sales['price'].var())

print('Standart deviation:')
print(sales['price'].std())
# Out:
# Variance:
# 20766.243824604506
# Standart deviation:
# 144.10497501684148

# %%
print(sales['price'].sort_values(ascending=False))
# Out:
# 528    1500.05
# 565    1325.16
# 710    1201.75
# 599    1177.05
# 3      1034.55
#         ...
# 870       1.61
# 307       1.42
# 780       1.23
# 343       0.76
# 431       0.66
# Name: price, Length: 1000, dtype: float64

# %% [markdown]
# # Фильтрация (loc[], iloc[])

# %%
import pandas as pd
import numpy as np

# %%
sales = pd.read_csv('sales.csv')

# %%
print(sales.loc[:4, ['product_code', 'product_group']])
# Out:
#    product_code product_group
# 0          4187           PG2
# 1          4195           PG2
# 2          4204           PG2
# 3          4219           PG2
# 4          4718           PG2

# %%
print(sales.iloc[[5, 6, 7, 8], [0, 1]])
# Out:
#    product_code product_group
# 5          5630           PG4
# 6          5631           PG4
# 7          5634           PG4
# 8          2650           PG4

# %%
print(sales.iloc[5:9, :2])
# Out:
#    product_code product_group
# 5          5630           PG4
# 6          5631           PG4
# 7          5634           PG4
# 8          2650           PG4

# %%
df = pd.DataFrame(
    np.random.randint(10, size=(4,4)),
    index = ['a', 'b', 'c', 'd'],
    columns = ['col_a', 'col_b', 'col_c', 'col_d']
)

print(df)
# Out:
#    col_a  col_b  col_c  col_d
# a      1      9      6      0
# b      7      8      0      6
# c      0      0      2      5
# d      9      4      0      1

# %%
print(df.loc[['b', 'd'], ['col_a', 'col_c']])
# Out:
#    col_a  col_c
# b      7      0
# d      9      0

# %% [markdown]
# ### Пример

# %%
# У вас есть DataFrame с данными о продажах товаров. Нужно выбрать третью и четвертую строки, а также первые два столбца.

# Пример ввода:

data = {
    'Product': ['Laptop', 'Smartphone', 'Tablet', 'Headphones'],
    'Price': [1000, 700, 300, 100],
    'Quantity': [5, 8, 3, 10]
}

df = pd.DataFrame(data)

                  
# Выход:

#      Product  Price
# 2     Tablet    300
# 3  Headphones    100

# %%
df
# Out:
#       Product  Price  Quantity
# 0      Laptop   1000         5
# 1  Smartphone    700         8
# 2      Tablet    300         3
# 3  Headphones    100        10

# %%
def solution(df):
    result = df.iloc[[2, 3], [0, 1]] # df.loc[[2:3], [0:1]]

    return result

# %%
print(solution(df))
# Out:
#       Product  Price
# 2      Tablet    300
# 3  Headphones    100

# %% [markdown]
# ### Пример №2

# %%
# Используя метод loc, выберите первые 5 строк и столбцы с названиями product_code и product_group.

# Пример ввода:

df = pd.DataFrame({
    "product_code": ["A001", "A002", "A003", "A004", "A005", "A006"],
    "product_group": ["Group1", "Group2", "Group3", "Group4", "Group5", "Group6"],
    "price": [100, 200, 300, 400, 500, 600]
})

                  
# Выход:

#   product_code product_group
# 0         A001        Group1
# 1         A002        Group2
# 2         A003        Group3
# 3         A004        Group4
# 4         A005        Group5

# %%
def solution(df):
    result = df.loc[:4, ['product_code', 'product_group']]

    return result

# %%
print(solution(df))
# Out:
#   product_code product_group
# 0         A001        Group1
# 1         A002        Group2
# 2         A003        Group3
# 3         A004        Group4
# 4         A005        Group5

# %% [markdown]
# # Фильтрация по столбцам и условиям

# %%
sales = pd.read_csv("sales.csv")
selected_columns = ['product_code', 'price']
print(sales[selected_columns])
# Out:
#      product_code    price
# 0            4187   569.91
# 1            4195   712.41
# 2            4204   854.91
# 3            4219  1034.55
# 4            4718    26.59
# ..            ...      ...
# 995          8048    11.39
# 996          8050     3.32
# 997           952    61.74
# 998          1307    42.74
# 999          3018    18.99
#
# [1000 rows x 2 columns]

# %%
print(sales[['product_code', 'price']])
# Out:
#      product_code    price
# 0            4187   569.91
# 1            4195   712.41
# 2            4204   854.91
# 3            4219  1034.55
# 4            4718    26.59
# ..            ...      ...
# 995          8048    11.39
# 996          8050     3.32
# 997           952    61.74
# 998          1307    42.74
# 999          3018    18.99
#
# [1000 rows x 2 columns]

# %%
sales_filtered = sales[sales.product_group == 'PG2']
sales_filtered
# Out:
#      product_code product_group  stock_qty    cost    price  last_week_sales  \
# 0            4187           PG2        498  420.76   569.91               13
# 1            4195           PG2        473  545.64   712.41               16
# 2            4204           PG2        968  640.42   854.91               22
# 3            4219           PG2        241  869.69  1034.55               14
# 4            4718           PG2       1401   12.54    26.59               50
# ..            ...           ...        ...     ...      ...              ...
# 973          6341           PG2       1274   12.06    18.99               39
# 979          2218           PG2       3049    8.20    16.14              148
# 980          2219           PG2       3525    9.02    16.14              164
# 997           952           PG2       5388   37.71    61.74              331
# 998          1307           PG2      44996   31.44    42.74             1772
#
#      last_month_sales
# 0                  58
# 1                  58
# 2                  88
# 3                  45
# 4                 285
# ..                ...
# 973               181
# 979               555
# 980               657
# 997              1041
# 998              6394
#
# [75 rows x 7 columns]

# %%
sales_filtered2 = sales[sales['product_group'] == 'PG2']
sales_filtered2
# Out:
#      product_code product_group  stock_qty    cost    price  last_week_sales  \
# 0            4187           PG2        498  420.76   569.91               13
# 1            4195           PG2        473  545.64   712.41               16
# 2            4204           PG2        968  640.42   854.91               22
# 3            4219           PG2        241  869.69  1034.55               14
# 4            4718           PG2       1401   12.54    26.59               50
# ..            ...           ...        ...     ...      ...              ...
# 973          6341           PG2       1274   12.06    18.99               39
# 979          2218           PG2       3049    8.20    16.14              148
# 980          2219           PG2       3525    9.02    16.14              164
# 997           952           PG2       5388   37.71    61.74              331
# 998          1307           PG2      44996   31.44    42.74             1772
#
#      last_month_sales
# 0                  58
# 1                  58
# 2                  88
# 3                  45
# 4                 285
# ..                ...
# 973               181
# 979               555
# 980               657
# 997              1041
# 998              6394
#
# [75 rows x 7 columns]

# %%
sales_filtered.equals(sales_filtered2)
# Out:
# True

# %%
sales[sales['price'] > 100]
# Out:
#      product_code product_group  stock_qty    cost    price  last_week_sales  \
# 0            4187           PG2        498  420.76   569.91               13
# 1            4195           PG2        473  545.64   712.41               16
# 2            4204           PG2        968  640.42   854.91               22
# 3            4219           PG2        241  869.69  1034.55               14
# 8            2650           PG4        239   59.40   111.06               15
# ..            ...           ...        ...     ...      ...              ...
# 865          3012           PG5       1079  140.13   189.91               39
# 867          5486           PG5        756   61.60   104.41               67
# 892          2971           PG1        234  124.69   180.41               20
# 929          1600           PG6        487   78.00   137.66               13
# 966          5630           PG4        545   99.83   161.49               16
#
#      last_month_sales
# 0                  58
# 1                  58
# 2                  88
# 3                  45
# 8                  38
# ..                ...
# 865               205
# 867               175
# 892                47
# 929                48
# 966                52
#
# [140 rows x 7 columns]

# %%
sales_filtered = sales[(sales["price"] > 100) & (sales["stock_qty"] < 400)]

print(sales_filtered[["price","stock_qty"]].head())
# Out:
#        price  stock_qty
# 3    1034.55        241
# 8     111.06        239
# 165   208.91        244
# 186   427.41        369
# 199   104.49        144

# %%
sales_filtered = sales[(sales["product_group"] == "PG1") | (sales["product_group"] == "PG2")]
print(sales_filtered)
# Out:
#      product_code product_group  stock_qty    cost    price  last_week_sales  \
# 0            4187           PG2        498  420.76   569.91               13
# 1            4195           PG2        473  545.64   712.41               16
# 2            4204           PG2        968  640.42   854.91               22
# 3            4219           PG2        241  869.69  1034.55               14
# 4            4718           PG2       1401   12.54    26.59               50
# ..            ...           ...        ...     ...      ...              ...
# 975          4594           PG1        762   42.70    75.99               58
# 979          2218           PG2       3049    8.20    16.14              148
# 980          2219           PG2       3525    9.02    16.14              164
# 997           952           PG2       5388   37.71    61.74              331
# 998          1307           PG2      44996   31.44    42.74             1772
#
#      last_month_sales
# 0                  58
# 1                  58
# 2                  88
# 3                  45
# 4                 285
# ..                ...
# 975               156
# 979               555
# 980               657
# 997              1041
# 998              6394
#
# [114 rows x 7 columns]

# %%
print(sales[sales['product_group'].isin(['PG1', 'PG2', 'PG3'])])
# Out:
#      product_code product_group  stock_qty    cost    price  last_week_sales  \
# 0            4187           PG2        498  420.76   569.91               13
# 1            4195           PG2        473  545.64   712.41               16
# 2            4204           PG2        968  640.42   854.91               22
# 3            4219           PG2        241  869.69  1034.55               14
# 4            4718           PG2       1401   12.54    26.59               50
# ..            ...           ...        ...     ...      ...              ...
# 975          4594           PG1        762   42.70    75.99               58
# 979          2218           PG2       3049    8.20    16.14              148
# 980          2219           PG2       3525    9.02    16.14              164
# 997           952           PG2       5388   37.71    61.74              331
# 998          1307           PG2      44996   31.44    42.74             1772
#
#      last_month_sales
# 0                  58
# 1                  58
# 2                  88
# 3                  45
# 4                 285
# ..                ...
# 975               156
# 979               555
# 980               657
# 997              1041
# 998              6394
#
# [153 rows x 7 columns]

# %%
print(sales[~sales["product_group"].isin(["PG1", "PG2", "PG3"])])
# Out:
#      product_code product_group  stock_qty   cost   price  last_week_sales  \
# 5            5630           PG4        287   5.85    7.59               24
# 6            5631           PG4        262   9.56   10.44               35
# 7            5634           PG4        205  14.15   18.04               14
# 8            2650           PG4        239  59.40  111.06               15
# 9            5647           PG4        352   5.85   13.29               37
# ..            ...           ...        ...    ...     ...              ...
# 993          7950           PG4        435   8.73   16.14               17
# 994          8046           PG4        409  12.32   11.39               16
# 995          8048           PG4        415  11.99   11.39               28
# 996          8050           PG4        -10   1.32    3.32               14
# 999          3018           PG5       1697   4.68   18.99               19
#
#      last_month_sales
# 5                 116
# 6                 130
# 7                  53
# 8                  38
# 9                 108
# ..                ...
# 993               112
# 994                22
# 995                60
# 996                11
# 999                52
#
# [847 rows x 7 columns]

# %%
print(sales.query('price > 100'))
# Out:
#      product_code product_group  stock_qty    cost    price  last_week_sales  \
# 0            4187           PG2        498  420.76   569.91               13
# 1            4195           PG2        473  545.64   712.41               16
# 2            4204           PG2        968  640.42   854.91               22
# 3            4219           PG2        241  869.69  1034.55               14
# 8            2650           PG4        239   59.40   111.06               15
# ..            ...           ...        ...     ...      ...              ...
# 865          3012           PG5       1079  140.13   189.91               39
# 867          5486           PG5        756   61.60   104.41               67
# 892          2971           PG1        234  124.69   180.41               20
# 929          1600           PG6        487   78.00   137.66               13
# 966          5630           PG4        545   99.83   161.49               16
#
#      last_month_sales
# 0                  58
# 1                  58
# 2                  88
# 3                  45
# 8                  38
# ..                ...
# 865               205
# 867               175
# 892                47
# 929                48
# 966                52
#
# [140 rows x 7 columns]

# %%
sales_filtered = sales.query("price > 100 and stock_qty < 400")
sales_filtered
# Out:
#      product_code product_group  stock_qty     cost    price  last_week_sales  \
# 3            4219           PG2        241   869.69  1034.55               14
# 8            2650           PG4        239    59.40   111.06               15
# 165          1657           PG5        244   162.33   208.91               14
# 186          7269           PG5        369   388.49   427.41               13
# 199          3530           PG4        144    57.98   104.49               16
# 215          2093           PG5        189   656.19   740.91               12
# 368          7957           PG1        320   459.80   750.41               21
# 437          9820           PG5        169    56.10   109.16               13
# 443          2751           PG5        386    62.83   104.41               20
# 445          2756           PG5        323    62.83   104.41               23
# 478          2646           PG5        332   700.14   712.41               18
# 490          2533           PG5        274    94.05   151.91               31
# 503          7745           PG4        305    84.58   170.99               13
# 504          1925           PG4         64   621.50   949.91               12
# 512          8488           PG2        103   100.10   170.91               23
# 528          9692           PG1         68  1243.00  1500.05               26
# 529          9693           PG1        373   480.14   812.16               18
# 534          9168           PG5        266   113.88   170.91               13
# 551          5287           PG5        218   289.00   370.41               16
# 552          5703           PG5        152   549.41   569.91               23
# 554          9835           PG5         39    61.44   104.41               13
# 558          6300           PG4        313   176.00   227.91               23
# 578          7597           PG5        293   681.27   664.91               13
# 586          7848           PG4        173    94.60   170.91               12
# 599          1941           PG1        213   847.00  1177.05               18
# 600          1942           PG1        223   424.60   655.41               20
# 610          7154           PG5        313    55.00   104.41               31
# 634          2430           PG3        161    89.38   180.41               17
# 661          7729           PG5        332    80.19   118.66               14
# 671          6470           PG5        321    94.60   170.99               19
# 710          4140           PG1         92   803.00  1201.75               12
# 721          4148           PG1        255   405.10   612.66               18
# 722          4150           PG1         22   405.10   612.66               14
# 728          6958           PG5        387   355.61   308.66               33
# 731          6966           PG5        252   355.61   308.66               17
# 748           662           PG6        383    57.64   123.41               32
# 749           667           PG6        130   115.17   208.91               18
# 753          8893           PG4        355   137.50   189.91               13
# 788          9668           PG4        181    69.30   142.41               16
# 826          8692           PG2        176   261.07   446.41               18
# 827          8693           PG2        157   197.63   360.91               19
# 828          8695           PG2        172   197.63   379.91               28
# 829          8696           PG2        132   296.43   484.41               14
# 830          8697           PG2        116   391.61   569.91               12
# 842          3846           PG4        100   114.92   194.66               12
# 892          2971           PG1        234   124.69   180.41               20
#
#      last_month_sales
# 3                  45
# 8                  38
# 165                48
# 186                49
# 199                51
# 215                44
# 368               100
# 437                26
# 443                75
# 445                56
# 478                27
# 490                93
# 503                58
# 504                31
# 512                54
# 528                94
# 529                54
# 534                35
# 551                51
# 552                39
# 554                22
# 558                85
# 578                13
# 586                34
# 599                72
# 600                63
# 610                91
# 634                57
# 661                34
# 671                84
# 710                24
# 721                39
# 722                29
# 728               131
# 731                47
# 748               106
# 749                34
# 753                43
# 788                44
# 826                86
# 827                94
# 828                54
# 829                60
# 830                78
# 842                22
# 892                47

# %%
print(sales_filtered[["product_code","price","stock_qty"]].head())
# Out:
#      product_code    price  stock_qty
# 3            4219  1034.55        241
# 8            2650   111.06        239
# 165          1657   208.91        244
# 186          7269   427.41        369
# 199          3530   104.49        144

# %%
sales_filtered = sales.query("product_group == 'PG2'")
print(sales_filtered[sales_filtered['product_group'] != 'PG2'])
# Out:
# Empty DataFrame
# Columns: [product_code, product_group, stock_qty, cost, price, last_week_sales, last_month_sales]
# Index: []

# %% [markdown]
# ### Пример

# %%
# Отфильтруйте товары из DataFrame sales, у которых цена больше 200 и количество на складе меньше 100.

# Вход:

sales = pd.DataFrame({
    'product_code': ['P001', 'P002', 'P003', 'P004'],
    'product_group': ['PG1', 'PG3', 'PG2', 'PG3'],
    'price': [150, 250, 50, 400],
    'stock_qty': [300, 80, 150, 40]
})

                  
# Выход:

#   product_code product_group  price  stock_qty
# 1         P002           PG3    250         80
# 3         P004           PG3    400         40

# %%
def solution(df):
    result = df[(df['price'] > 200) & (df['stock_qty'] < 100)]

    return result

# %%
solution(sales)
# Out:
#   product_code product_group  price  stock_qty
# 1         P002           PG3    250         80
# 3         P004           PG3    400         40

# %% [markdown]
# ### Пример 2

# %%
# В DataFrame содержится информация о продажах товаров. Отфильтруйте товары, принадлежащие к товарной группе "PG1" или "PG4", и у которых цена меньше 50 долларов.

# Инпут:

sales = pd.DataFrame({
    "product_code": [101, 102, 103, 104],
    "product_group": ["PG1", "PG2", "PG1", "PG4"],
    "price": [40, 60, 30, 45]
})

                  
# Аутпут:

# pd.DataFrame({
#     "product_code": [101, 103, 104],
#     "product_group": ["PG1", "PG1", "PG4"],
#     "price": [40, 30, 45]
# })

# %%
def solution(df):
    result = df[(df['product_group'].isin(['PG1', 'PG4'])) & (df['price'] < 50)]

    return result

# %%
solution(sales)
# Out:
#    product_code product_group  price
# 0           101           PG1     40
# 2           103           PG1     30
# 3           104           PG4     45

# %% [markdown]
# ## Проверочная

# %% [markdown]
# ### 1 задание

# %%
# Выберите товары, у которых цена больше 200 и количество на складе меньше 150.

# Вход:


data = {
    'product_name': ['Laptop', 'Smartphone', 'Tablet', 'Headphones'],
    'price': [1000, 700, 150, 80],
    'stock_qty': [50, 120, 300, 400]
}

df = pd.DataFrame(data)

                  
# Выход:

#   product_name  price  stock_qty
# 0       Laptop   1000         50
# 1   Smartphone    700        120

# %%
df
# Out:
#   product_name  price  stock_qty
# 0       Laptop   1000         50
# 1   Smartphone    700        120
# 2       Tablet    150        300
# 3   Headphones     80        400

# %%
def solution(df):
    result = df[(df['price'] > 200) & (df['stock_qty'] < 150)]

    return result

# %%
print(solution(df))
# Out:
#   product_name  price  stock_qty
# 0       Laptop   1000         50
# 1   Smartphone    700        120

# %% [markdown]
# ### 2 задание

# %%
# Отфильтруйте товары, которые принадлежат к категориям "Electronics" или "Furniture" и имеют цену меньше 500. Затем выведите столбцы "product_name", "price", и "stock_qty".

# Вход:

data = {
    'product_name': ['Laptop', 'Smartphone', 'Tablet', 'Sofa', 'Chair'],
    'product_group': ['Electronics', 'Electronics', 'Electronics', 'Furniture', 'Furniture'],
    'price': [1000, 700, 300, 400, 150],
    'stock_qty': [50, 120, 300, 10, 50]
}

df = pd.DataFrame(data)

                  
# Вывод:

#   product_name  price  stock_qty
# 2       Tablet    300        300
# 3         Sofa    400         10
# 4        Chair    150         50

# %%
def solution(df):
    result = df[(df['product_group'].isin(['Electronics', 'Furniture'])) & (df['price'] < 500)]

    return result[['product_name', 'price', 'stock_qty']]

# %%
display(solution(df))
# Out:
#   product_name  price  stock_qty
# 2       Tablet    300        300
# 3         Sofa    400         10
# 4        Chair    150         50

# %% [markdown]
# ### 3 задание

# %%
# Дан DataFrame с информацией о книгах. Отфильтруйте все книги, написанные автором "J.K. Rowling", и выведите название книги и количество проданных копий.

# Вход:

data = {
    'title': ['Harry Potter', 'The Hobbit', 'Fantastic Beasts', 'Silmarillion'],
    'author': ['J.K. Rowling', 'J.R.R. Tolkien', 'J.K. Rowling', 'J.R.R. Tolkien'],
    'sold_copies': [5000000, 3000000, 2000000, 1000000]
}

                  
# Выход:

#            title  sold_copies
# 0   Harry Potter      5000000
# 2  Fantastic Beasts    2000000

# %%
df = pd.DataFrame(data)

# %%
import pandas as pd

def solution(df):
    result = df[df['author'] == 'J.K. Rowling']

    return result[['title', 'sold_copies']]

# %%
display(solution(df))
# Out:
#               title  sold_copies
# 0      Harry Potter      5000000
# 2  Fantastic Beasts      2000000

# %% [markdown]
# # Работа с типами данных и пропущенными значениями

# %%
import pandas as pd
import numpy as np

# %%
staff = pd.read_csv('staff.csv')
staff
# Out:
#                name             city date_of_birth  start_date   salary  \
# 0          John Doe      Houston, TX    1998-11-04  2018-08-11  $65,000
# 1          Jane Doe     San Jose, CA    1995-08-05  2017-08-24  $70,000
# 2        Matt smith       Dallas, TX    1996-11-25  2020-04-16  $58,500
# 3     Ashley Harris        Miami, FL    1995-01-08  2021-02-11  $49,500
# 4  Jonathan targett  Santa Clara, CA    1998-08-14  2020-09-01  $62,000
# 5         Hale Cole      Atlanta, GA    2000-10-24  2021-10-20  $54,500
#
#         department
# 0       Accounting
# 1    Field Quality
# 2  human resources
# 3       accounting
# 4    field quality
# 5      engineering

# %%
print(f"\nStaff data frame has the following columns: \n{list(staff.columns)}\n")
# Out:
# Staff data frame has the following columns:
# ['name', 'city', 'date_of_birth', 'start_date', 'salary', 'department']

# %%
print(staff['name'].str[0])
# Out:
# 0    J
# 1    J
# 2    M
# 3    A
# 4    J
# 5    H
# Name: name, dtype: object

# %%
print(staff['name'].str[:3])
# Out:
# 0    Joh
# 1    Jan
# 2    Mat
# 3    Ash
# 4    Jon
# 5    Hal
# Name: name, dtype: object

# %%
print(staff["name"].str[-2:])
# Out:
# 0    oe
# 1    oe
# 2    th
# 3    is
# 4    tt
# 5    le
# Name: name, dtype: object

# %%
print(staff["name"].str[1::2])
# Out:
# 0        onDe
# 1        aeDe
# 2       atsih
# 3      slyHri
# 4    oahntret
# 5        aeCl
# Name: name, dtype: object

# %%
print(staff['name'].str.split(' '))
# Out:
# 0            [John, Doe]
# 1            [Jane, Doe]
# 2          [Matt, smith]
# 3       [Ashley, Harris]
# 4    [Jonathan, targett]
# 5           [Hale, Cole]
# Name: name, dtype: object

# %%
print(staff['name'].str.split(' ', expand=True))
# Out:
#           0        1
# 0      John      Doe
# 1      Jane      Doe
# 2      Matt    smith
# 3    Ashley   Harris
# 4  Jonathan  targett
# 5      Hale     Cole

# %%
staff['last_name'] = staff['name'].str.split(' ', expand=True)[1]
print(staff[['name', 'last_name']])
# Out:
#                name last_name
# 0          John Doe       Doe
# 1          Jane Doe       Doe
# 2        Matt smith     smith
# 3     Ashley Harris    Harris
# 4  Jonathan targett   targett
# 5         Hale Cole      Cole

# %%
# print(staff['name'] + ' - ' + staff['department'])
# Out:
# 0               John Doe - Accounting
# 1            Jane Doe - Field Quality
# 2        Matt smith - human resources
# 3          Ashley Harris - accounting
# 4    Jonathan targett - field quality
# 5             Hale Cole - engineering
# dtype: object

# %%
staff['name_lower'] = staff['name'].str.lower()
print(staff[['name', 'name_lower']])
# Out:
#                name        name_lower
# 0          John Doe          john doe
# 1          Jane Doe          jane doe
# 2        Matt smith        matt smith
# 3     Ashley Harris     ashley harris
# 4  Jonathan targett  jonathan targett
# 5         Hale Cole         hale cole

# %%
print(staff['department'].str.capitalize())
# Out:
# 0         Accounting
# 1      Field quality
# 2    Human resources
# 3         Accounting
# 4      Field quality
# 5        Engineering
# Name: department, dtype: object

# %%
staff["state"] = staff["city"].str[-2:]

staff["state"].replace(
    {"TX": "Texas", "CA": "California", "FL": "Florida", "GA": "Georgia"},
    inplace = True
)

print(staff["state"])
# Out:
# 0         Texas
# 1    California
# 2         Texas
# 3       Florida
# 4    California
# 5       Georgia
# Name: state, dtype: object

# %%
print(staff["city"].str.split(",", expand=True)[1].str.lower())
# Out:
# 0     tx
# 1     ca
# 2     tx
# 3     fl
# 4     ca
# 5     ga
# Name: 1, dtype: object

# %%
print(staff["department"], staff["department"].str.lower().replace("field quality","quality"))
# Out:
# 0         Accounting
# 1      Field Quality
# 2    human resources
# 3         accounting
# 4      field quality
# 5        engineering
# Name: department, dtype: object 0         accounting
# 1            quality
# 2    human resources
# 3         accounting
# 4            quality
# 5        engineering
# Name: department, dtype: object

# %% [markdown]
# ### 1 задание

# %%
# Объедините столбцы "Имя" и "Отдел" в одну строку с разделителем "-". Выведите новый объединённый столбец.

# Вход:

data = {'name': ['Alice Smith', 'Bob Johnson'], 'department': ['HR', 'Sales']}
df = pd.DataFrame(data)

                  
# Выход:

# 0    Alice Smith-HR
# 1    Bob Johnson-Sales

# %%
import pandas as pd

def solution(df):
    result = df['name'] + '-' + df['department']

    return result

# %%
print(solution(df))
# Out:
# 0       Alice Smith-HR
# 1    Bob Johnson-Sales
# dtype: object

# %% [markdown]
# ### 2 задание

# %%
# Разделите столбец "Имя" на два новых столбца: "Имя" и "Фамилия" (Гарантированно разделенные пробелом). Затем выведите получившиеся столбцы.

# Вход:

data = {'name': ['Alice Smith', 'Bob Johnson', 'Charlie Brown']}
df=pd.DataFrame(data)

                  
# Выход:

#     first_name last_name
# 0        Alice      Smith
# 1          Bob    Johnson
# 2      Charlie      Brown

# %%
def solution(df):
    result = pd.DataFrame(columns=['first_name', 'last_name'])
    result[['first_name', 'last_name']] = df['name'].str.split(' ', expand=True)

    return result

# %%
print(solution(df))
# Out:
#   first_name last_name
# 0      Alice     Smith
# 1        Bob   Johnson
# 2    Charlie     Brown

# %% [markdown]
# ### 3 задание

# %%
# Дан DataFrame с информацией о сотрудниках, включая их имена и даты найма в формате "дд/мм/гггг". Вам нужно:

# Извлечь только год из столбца "hire_date".
# Разделить столбец "name" на два новых столбца: "first_name" и "last_name".
# Объединить фамилию и год найма в один столбец с разделителем " - ".
# Преобразовать фамилию в верхний регистр в новом столбце.
# Вход:

data = {
    'name': ['Alice Smith', 'Bob Johnson', 'Charlie Brown'],
    'hire_date': ['15/03/2010', '22/07/2015', '01/01/2020']
}
df=pd.DataFrame(data)

                  
# Выход:

# first_name  last_name  year_hired          combined
# 0      Alice      Smith        2010         SMITH - 2010
# 1        Bob    Johnson        2015       JOHNSON - 2015
# 2    Charlie      Brown        2020         BROWN - 2020

                  
# Sample Input:

# Sample Output:

# True

# %%
def solution(df):
    result = pd.DataFrame(columns=['first_name', 'last_name', 'year_hired', 'combined'])
    result[['first_name', 'last_name']] = df['name'].str.split(' ', expand=True)
    result['year_hired'] = df['hire_date'].str[6:]
    result['combined'] = result['last_name'].str.upper() + ' - ' + result['year_hired']
    return result

# %%
display(solution(df))
# Out:
#   first_name last_name year_hired        combined
# 0      Alice     Smith       2010    SMITH - 2010
# 1        Bob   Johnson       2015  JOHNSON - 2015
# 2    Charlie     Brown       2020    BROWN - 2020

# %% [markdown]
# # Дата и время

# %%
mydate = pd.to_datetime("2021-11-10")

display(mydate)
# Out:
# Timestamp('2021-11-10 00:00:00')

# %%
first_date = pd.to_datetime("2021-10-10")
second_date = pd.to_datetime("2021-10-02")

diff = first_date - second_date

print(diff)
# Out:
# 8 days 00:00:00

# %%
staff = pd.read_csv('staff.csv')

staff = staff.astype({
    "date_of_birth": "datetime64[ns]",
    "start_date": "datetime64[ns]",
})

print(staff.dtypes)
# Out:
# name                     object
# city                     object
# date_of_birth    datetime64[ns]
# start_date       datetime64[ns]
# salary                   object
# department               object
# dtype: object

# %%
staff
# Out:
#                name             city date_of_birth start_date   salary  \
# 0          John Doe      Houston, TX    1998-11-04 2018-08-11  $65,000
# 1          Jane Doe     San Jose, CA    1995-08-05 2017-08-24  $70,000
# 2        Matt smith       Dallas, TX    1996-11-25 2020-04-16  $58,500
# 3     Ashley Harris        Miami, FL    1995-01-08 2021-02-11  $49,500
# 4  Jonathan targett  Santa Clara, CA    1998-08-14 2020-09-01  $62,000
# 5         Hale Cole      Atlanta, GA    2000-10-24 2021-10-20  $54,500
#
#         department
# 0       Accounting
# 1    Field Quality
# 2  human resources
# 3       accounting
# 4    field quality
# 5      engineering

# %%
mydate = pd.to_datetime("2021-10-10")

print(f"The year part is {mydate.year}")
print(f"The month part is {mydate.month}")
print(f"The week number part is {mydate.week}")
print(f"The day part is {mydate.day}")
# Out:
# The year part is 2021
# The month part is 10
# The week number part is 40
# The day part is 10

# %%
mydate.day_of_week
# Out:
# 6

# %%
mydate = pd.to_datetime("2021-10-10 14:30:00")

print(f"The hour part of mydate is {mydate.hour}")
print(f"The minute part of mydate is {mydate.minute}")
print(f"The second part of mydate is {mydate.second}")
# Out:
# The hour part of mydate is 14
# The minute part of mydate is 30
# The second part of mydate is 0

# %%
mydate.day_of_year
# Out:
# 283

# %%
dir(mydate)
# Out:
# ['__add__',
#  '__array_priority__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__pyx_vtable__',
#  '__radd__',
#  '__reduce__',
#  '__reduce_cython__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rsub__',
#  '__setattr__',
#  '__setstate__',
#  '__setstate_cython__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__weakref__',
#  '_creso',
#  '_date_repr',
#  '_from_dt64',
#  '_from_value_and_reso',
#  '_repr_base',
#  '_round',
#  '_time_repr',
#  '_value',
#  'as_unit',
#  'asm8',
#  'astimezone',
#  'ceil',
#  'combine',
#  'ctime',
#  'date',
#  'day',
#  'day_name',
#  'day_of_week',
#  'day_of_year',
#  'dayofweek',
#  'dayofyear',
#  'days_in_month',
#  'daysinmonth',
#  'dst',
#  'floor',
#  'fold',
#  'fromisocalendar',
#  'fromisoformat',
#  'fromordinal',
#  'fromtimestamp',
#  'hour',
#  'is_leap_year',
#  'is_month_end',
#  'is_month_start',
#  'is_quarter_end',
#  'is_quarter_start',
#  'is_year_end',
#  'is_year_start',
#  'isocalendar',
#  'isoformat',
#  'isoweekday',
#  'max',
#  'microsecond',
#  'min',
#  'minute',
#  'month',
#  'month_name',
#  'nanosecond',
#  'normalize',
#  'now',
#  'quarter',
#  'replace',
#  'resolution',
#  'round',
#  'second',
#  'strftime',
#  'strptime',
#  'time',
#  'timestamp',
#  'timetuple',
#  'timetz',
#  'to_datetime64',
#  'to_julian_date',
#  'to_numpy',
#  'to_period',
#  'to_pydatetime',
#  'today',
#  'toordinal',
#  'tz',
#  'tz_convert',
#  'tz_localize',
#  'tzinfo',
#  'tzname',
#  'unit',
#  'utcfromtimestamp',
#  'utcnow',
#  'utcoffset',
#  'utctimetuple',
#  'value',
#  'week',
#  'weekday',
#  'weekofyear',
#  'year']

# %%
vars(mydate)
# Out:
# {}

# %%
mydate = pd.to_datetime("2021-12-21 00:00:00")

print(f"The date part is {mydate.date()}")
print(f"The day part is {mydate.weekday()}")
print(f"The name of the month is {mydate.month_name()}")
print(f"The name of the day is {mydate.day_name()}")
# Out:
# The date part is 2021-12-21
# The day part is 1
# The name of the month is December
# The name of the day is Tuesday

# %%
staff["start_date"]
# Out:
# 0   2018-08-11
# 1   2017-08-24
# 2   2020-04-16
# 3   2021-02-11
# 4   2020-09-01
# 5   2021-10-20
# Name: start_date, dtype: datetime64[ns]

# %%
staff["start_month"] = staff["start_date"].dt.month # type: ignore

# %%
print(staff[["start_date", "start_month"]])
# Out:
#   start_date  start_month
# 0 2018-08-11            8
# 1 2017-08-24            8
# 2 2020-04-16            4
# 3 2021-02-11            2
# 4 2020-09-01            9
# 5 2021-10-20           10

# %%
staff["start_date"].dt.isocalendar() # type: ignore
# Out:
#    year  week  day
# 0  2018    32    6
# 1  2017    34    4
# 2  2020    16    4
# 3  2021     6    4
# 4  2020    36    2
# 5  2021    42    3

# %%
staff["raise_date"] = staff["start_date"] + pd.DateOffset(years=1)

display(staff[["start_date", "raise_date"]])
# Out:
#   start_date raise_date
# 0 2018-08-11 2019-08-11
# 1 2017-08-24 2018-08-24
# 2 2020-04-16 2021-04-16
# 3 2021-02-11 2022-02-11
# 4 2020-09-01 2021-09-01
# 5 2021-10-20 2022-10-20

# %%
staff["start_date"] + pd.DateOffset(months=6)
# Out:
# 0   2019-02-11
# 1   2018-02-24
# 2   2020-10-16
# 3   2021-08-11
# 4   2021-03-01
# 5   2022-04-20
# Name: start_date, dtype: datetime64[ns]

# %%
display(staff["start_date"] + pd.Timedelta(value=12, unit="W"))
# Out:
# 0   2018-11-03
# 1   2017-11-16
# 2   2020-07-09
# 3   2021-05-06
# 4   2020-11-24
# 5   2022-01-12
# Name: start_date, dtype: datetime64[ns]

# %%
display(staff["start_date"] + pd.Timedelta("12 W"))
# Out:
# 0   2018-11-03
# 1   2017-11-16
# 2   2020-07-09
# 3   2021-05-06
# 4   2020-11-24
# 5   2022-01-12
# Name: start_date, dtype: datetime64[ns]

# %% [markdown]
# ## Задача

# %%
# Кол время работы за день

data = {
    'employee': ['John'],
    'start_time': ['2023-09-10 08:00:00'],
    'end_time': ['2023-09-10 17:00:00']
}
df=pd.DataFrame(data)

# %%
def solution(df):
    df['end_time'] = pd.to_datetime(df['end_time'])
    df['start_time'] = pd.to_datetime(df['start_time'])
    df['work_duration'] = pd.to_datetime(df['end_time']) - pd.to_datetime(df['start_time'])

    return df

# %%
print(solution(df))
# Out:
#   employee          start_time            end_time   work_duration
# 0     John 2023-09-10 08:00:00 2023-09-10 17:00:00 0 days 09:00:00

# %% [markdown]
# # Пропущенные значения

# %%
staff = pd.read_csv('staff.csv')

# %%
df = pd.DataFrame({
    "A": [1, 2, 3, np.nan],
    "B": [2.4, 6.2, 5.1, np.nan],
    "C": ["foo","zoo","bar", np.nan]
})

display(df)
print(df)
# Out:
#      A    B    C
# 0  1.0  2.4  foo
# 1  2.0  6.2  zoo
# 2  3.0  5.1  bar
# 3  NaN  NaN  NaN
#      A    B    C
# 0  1.0  2.4  foo
# 1  2.0  6.2  zoo
# 2  3.0  5.1  bar
# 3  NaN  NaN  NaN

# %%
df["A"] = df["A"].astype(pd.Int64Dtype())

display(df)
# Out:
#       A    B    C
# 0     1  2.4  foo
# 1     2  6.2  zoo
# 2     3  5.1  bar
# 3  <NA>  NaN  NaN

# %%
df = pd.DataFrame({
    "A": [1, 2, 3, np.nan, 7],
    "B": [2.4, np.nan, 5.1, np.nan, 2.6],
    "C": [np.nan, "foo","zoo","bar", np.nan],
    "D": [11.5, np.nan, 6.2, 21.1, 8.7]
})

display(df)
display(df.isna())
# Out:
#      A    B    C     D
# 0  1.0  2.4  NaN  11.5
# 1  2.0  NaN  foo   NaN
# 2  3.0  5.1  zoo   6.2
# 3  NaN  NaN  bar  21.1
# 4  7.0  2.6  NaN   8.7
#        A      B      C      D
# 0  False  False   True  False
# 1  False   True  False   True
# 2  False  False  False  False
# 3   True   True  False  False
# 4  False  False   True  False

# %%
df = pd.DataFrame({
    "A": [1, 2, 3, np.nan, 7],
    "B": [2.4, np.nan, 5.1, np.nan, 2.6],
    "C": [np.nan, "foo","zoo","bar", np.nan],
    "D": [11.5, np.nan, 6.2, 21.1, 8.7]
})

display(df.isna().sum())
display(df.isna().sum().sum())
display(df.isna().sum(axis=1))
# Out:
# A    1
# B    2
# C    2
# D    1
# dtype: int64
# np.int64(6)
# 0    1
# 1    2
# 2    0
# 3    2
# 4    1
# dtype: int64

# %%
df = pd.DataFrame({
    "A": [1, 2, 3, np.nan, 7],
    "B": [2.4, np.nan, 5.1, np.nan, 2.6],
    "C": [np.nan, "foo","zoo","bar", np.nan],
    "D": [11.5, np.nan, 6.2, 21.1, 8.7],
    "E": [1, 2, 3, 4, 5]
})

display(df.dropna(axis=0, how='any'))
display(df.dropna(axis=1, how='any'))
# Out:
#      A    B    C    D  E
# 2  3.0  5.1  zoo  6.2  3
#    E
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
display(df.dropna(thresh=4))
# Out:
#      A    B    C     D  E
# 0  1.0  2.4  NaN  11.5  1
# 2  3.0  5.1  zoo   6.2  3
# 4  7.0  2.6  NaN   8.7  5

# %%
df.dropna(thresh=4, inplace=True)

display(df)
# Out:
#      A    B    C     D  E
# 0  1.0  2.4  NaN  11.5  1
# 2  3.0  5.1  zoo   6.2  3
# 4  7.0  2.6  NaN   8.7  5

# %%
# Замена NaN
df = pd.DataFrame({
    "A": [1, 2, 3, np.nan, 7],
    "B": [2.4, np.nan, 5.1, np.nan, 2.6],
    "C": [np.nan, "foo","zoo","bar", np.nan],
    "D": [11.5, np.nan, 6.2, 21.1, 8.7],
    "E": [1, 2, 3, 4, 5]
})

display(df['A'].fillna(value=df['A'].mean()))
# Out:
# 0    1.00
# 1    2.00
# 2    3.00
# 3    3.25
# 4    7.00
# Name: A, dtype: float64

# %%
df = pd.DataFrame({
    "A": [1, 2, 3, np.nan, 7],
    "B": [2.4, np.nan, 5.1, np.nan, 2.6],
    "C": [np.nan, "foo","zoo","bar", np.nan],
    "D": [11.5, np.nan, 6.2, 21.1, 8.7],
    "E": [1, 2, 3, 4, 5]
})

print(df.fillna({"A": df['A'].mean(), "D": df['D'].mean()}))
# Out:
#       A    B    C       D  E
# 0  1.00  2.4  NaN  11.500  1
# 1  2.00  NaN  foo  11.875  2
# 2  3.00  5.1  zoo   6.200  3
# 3  3.25  NaN  bar  21.100  4
# 4  7.00  2.6  NaN   8.700  5

# %%
df = pd.DataFrame({
    "A": [1, 2, 3, np.nan, 7],
    "B": [2.4, np.nan, 5.1, np.nan, 2.6],
    "C": [np.nan, "foo","zoo","bar", np.nan],
    "D": [11.5, np.nan, 6.2, 21.1, 8.7],
    "E": [1, 2, 3, 4, 5]
})

print("Filling backward")
print(df["A"].bfill())

print("\nFilling forward")
print(df["A"].ffill())
# Out:
# Filling backward
# 0    1.0
# 1    2.0
# 2    3.0
# 3    7.0
# 4    7.0
# Name: A, dtype: float64
#
# Filling forward
# 0    1.0
# 1    2.0
# 2    3.0
# 3    3.0
# 4    7.0
# Name: A, dtype: float64

# %%
df = pd.DataFrame({
    "A": [1, 2, np.nan, np.nan, 8]
})

print("Without the limit parameter")
print(df.bfill())

print("\nWith the limit parameter")
print(df.bfill(limit=1))
# Out:
# Without the limit parameter
#      A
# 0  1.0
# 1  2.0
# 2  8.0
# 3  8.0
# 4  8.0
#
# With the limit parameter
#      A
# 0  1.0
# 1  2.0
# 2  NaN
# 3  8.0
# 4  8.0

# %% [markdown]
# ## Задача

# %%
data = {
    'name': ['Anna', 'Mike', 'Sophia'],
    'age': [29, None, 34]
}
df=pd.DataFrame(data)

# %%
def solution(df):
    result = pd.concat([df['name'], df['age'].fillna(value=df['age'].mean())], axis=1)

    return result

# %%
display(solution(df))
# Out:
#      name   age
# 0    Anna  29.0
# 1    Mike  31.5
# 2  Sophia  34.0

# %% [markdown]
# ## Задача 2

# %%
df = pd.DataFrame({
    "A": [1, 2, np.nan, 5],
    "B": [np.nan, 5, 6, 7],
    "C": ["foo", np.nan, "foo", "bar"]
})

df
# Out:
#      A    B    C
# 0  1.0  NaN  foo
# 1  2.0  5.0  NaN
# 2  NaN  6.0  foo
# 3  5.0  7.0  bar

# %%
def solution(df):
    
    for col in df.columns:
        if pd.api.types.is_numeric_dtype(df[col]):
            df[col] = df[col].fillna(df[col].mean())
        else:
            df[col] = df[col].fillna(df[col].mode()[0])

    return df

# %%
display(solution(df))
# Out:
#           A    B    C
# 0  1.000000  6.0  foo
# 1  2.000000  5.0  foo
# 2  2.666667  6.0  foo
# 3  5.000000  7.0  bar

# %% [markdown]
# # Анализ данных, визуализация

# %%
import pandas as pd

grocery = pd.read_csv("grocery.csv")

print("The size of the DataFrame:")
print(grocery.shape)

print("\nThe column names are:")
print(list(grocery.columns))

grocery.head(5)
# Out:
# The size of the DataFrame:
# (35, 7)
#
# The column names are:
# ['product_code', 'product_description', 'product_group', 'sales_date', 'price', 'sales_quantity', 'unit']
#    product_code product_description product_group  sales_date  price  \
# 0          1102              orange         fruit  2021-11-12   2.60
# 1          1003               onion     vegetable  2021-11-28   2.29
# 2          1202          yogurt-1kg         dairy  2021-11-30   6.90
# 3          1103               apple         fruit  2021-11-13   1.90
# 4          1001              tomato     vegetable  2021-11-24   2.89
#
#    sales_quantity unit
# 0            30.0   kg
# 1            38.0   kg
# 2            37.0  pcs
# 3            20.0   kg
# 4            39.0   kg

# %% [markdown]
# ## Функция groupby

# %%
grocery.groupby('product_group').mean(numeric_only=True)
# Out:
#                product_code     price  sales_quantity
# product_group
# dairy           1202.166667  8.000000       30.333333
# fruit           1102.833333  3.016667       29.333333
# vegetable       1002.000000  3.162727       30.100000

# %%
grocery[['product_group', 'price']].groupby('product_group').mean()
# Out:
#                   price
# product_group
# dairy          8.000000
# fruit          3.016667
# vegetable      3.162727

# %%
grocery.groupby('product_group').agg(avg_price = ('price', 'mean'))
# Out:
#                avg_price
# product_group
# dairy           8.000000
# fruit           3.016667
# vegetable       3.162727

# %%
grocery.groupby('product_group').agg(avg_price = ('price', 'mean'), total_sales = ('sales_quantity', 'sum'))
# Out:
#                avg_price  total_sales
# product_group
# dairy           8.000000        364.0
# fruit           3.016667        352.0
# vegetable       3.162727        301.0

# %%
grocery.groupby('product_description').agg(avg_price = ('price', 'mean'), total_sales = ('sales_quantity', 'sum')
                                     ).sort_values(by='total_sales', ascending=False)
# Out:
#                      avg_price  total_sales
# product_description
# yogurt-1kg            6.614286        258.0
# apple                 2.140000        131.0
# tomato                3.065000        113.0
# onion                 2.215000        105.0
# orange                2.600000        102.0
# grape                 4.400000         92.0
# cucumber              4.556667         83.0
# butter-0.25kg        11.233333         82.0
# plum                  4.500000         27.0
# milk-1L                    NaN         24.0

# %%
display(grocery.groupby(['product_description', 'product_group']).agg(avg_price = ('price', 'mean'), total_sales = ('sales_quantity', 'sum')).sort_values('total_sales', ascending=False))
# Out:
#                                    avg_price  total_sales
# product_description product_group
# yogurt-1kg          dairy           6.614286        258.0
# apple               fruit           2.140000        131.0
# tomato              vegetable       3.065000        113.0
# onion               vegetable       2.215000        105.0
# orange              fruit           2.600000        102.0
# grape               fruit           4.400000         92.0
# cucumber            vegetable       4.556667         83.0
# butter-0.25kg       dairy          11.233333         82.0
# plum                fruit           4.500000         27.0
# milk-1L             dairy                NaN         24.0

# %% [markdown]
# ### Задача 1

# %%
# У вас есть DataFrame с информацией о товарах, содержащий столбцы product_description (описание товара),
# price (цена товара) и sales_quantity (количество продаж). Ваша задача — вычислить среднюю цену и общее количество продаж
# для каждого товара, а затем отсортировать результат по количеству продаж в порядке убывания.

# Вход:

data = {
    'product_description': ['Apple', 'Banana', 'Carrot', 'Apple'],
    'price': [1.00, 0.50, 1.50, 1.00],
    'sales_quantity': [200, 150, 100, 300]
}
df=pd.DataFrame(data)

                      
                  

# Выход:

#                     avg_price  total_sales
# product_description                         
# Apple                   1.00          500
# Banana                  0.50          150
# Carrot                  1.50          100

# %%
def solution(df):
    result = df.groupby('product_description').agg(
        avg_price = ('price', 'mean'),
        total_sales = ('sales_quantity', sum)
    ).sort_values('total_sales', ascending=False)

    return result

# %%
display(solution(df))
# Out:
# C:\Users\melni\AppData\Local\Temp\ipykernel_11028\1700929730.py:2: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   result = df.groupby('product_description').agg(
#                      avg_price  total_sales
# product_description
# Apple                      1.0          500
# Banana                     0.5          150
# Carrot                     1.5          100

# %% [markdown]
# ### Задание 2

# %%
# Рассчитайте среднюю цену и общее количество продаж для каждой группы товаров, используя функцию groupby,
# и отсортируйте результат по средней цене по убыванию.

# Входные данные:

df = pd.DataFrame({
    "product_group": ["Fruit", "Vegetable", "Fruit", "Meat", "Meat"],
    "price": [5, 3, 6, 10, 12],
    "sales_quantity": [20, 15, 30, 5, 8]
})

                      
                  

# Выходные данные:

#              avg_price  total_sales
# product_group                        
# Meat               11.0           13
# Fruit               5.5           50
# Vegetable           3.0           15

# %%
def solution(df):
    result = df.groupby('product_group').agg(
        avg_price = ('price', 'mean'),
        total_sales = ('sales_quantity', 'sum')
    ).sort_values('avg_price', ascending=False)

    return result

# %%
display(solution(df))
# Out:
#                avg_price  total_sales
# product_group
# Meat                11.0           13
# Fruit                5.5           50
# Vegetable            3.0           15

# %% [markdown]
# ### Задание 3

# %%
# Найдите минимальную и максимальную цену для каждого описания продукта и отсортируйте результат по минимальной цене по возрастанию.

# Инпут:

df = pd.DataFrame({
    "product_description": ["Apple", "Banana", "Apple", "Beef", "Banana"],
    "price": [5, 2, 7, 10, 3]
})

                      
                  

# Аутпут:

#                   min_price  max_price
# product_description                     
# Banana                    2          3
# Apple                     5          7
# Beef                     10         10

# %%
def solution(df):
    result = df.groupby('product_description').agg(
        min_price = ('price', 'min'),
        max_price = ('price', 'max')
        ).sort_values('min_price')

    return result

# %%
solution(df)
# Out:
#                      min_price  max_price
# product_description
# Banana                       2          3
# Apple                        5          7
# Beef                        10         10

# %% [markdown]
# ## Pivot table

# %%
grocery = pd.read_csv('grocery.csv')
display(grocery.head())
# Out:
#    product_code product_description product_group  sales_date  price  \
# 0          1102              orange         fruit  2021-11-12   2.60
# 1          1003               onion     vegetable  2021-11-28   2.29
# 2          1202          yogurt-1kg         dairy  2021-11-30   6.90
# 3          1103               apple         fruit  2021-11-13   1.90
# 4          1001              tomato     vegetable  2021-11-24   2.89
#
#    sales_quantity unit
# 0            30.0   kg
# 1            38.0   kg
# 2            37.0  pcs
# 3            20.0   kg
# 4            39.0   kg

# %%
grocery['sales_date'] = grocery['sales_date'].astype('datetime64[ns]')
grocery['week'] = grocery['sales_date'].dt.isocalendar().week

grocery.head()
# Out:
#    product_code product_description product_group sales_date  price  \
# 0          1102              orange         fruit 2021-11-12   2.60
# 1          1003               onion     vegetable 2021-11-28   2.29
# 2          1202          yogurt-1kg         dairy 2021-11-30   6.90
# 3          1103               apple         fruit 2021-11-13   1.90
# 4          1001              tomato     vegetable 2021-11-24   2.89
#
#    sales_quantity unit  week
# 0            30.0   kg    45
# 1            38.0   kg    47
# 2            37.0  pcs    48
# 3            20.0   kg    45
# 4            39.0   kg    47

# %%
display(pd.pivot_table(
    data=grocery,
    values='sales_quantity',
    index='product_group',
    columns='week',
    aggfunc='sum'
))
# Out:
# week             44    45     46     47    48
# product_group
# dairy          46.0  83.0  130.0   68.0  37.0
# fruit          99.0  50.0   96.0   74.0  33.0
# vegetable      29.0  51.0   59.0  162.0   0.0

# %%
display(pd.pivot_table(
    data = grocery, 
    values = "price", 
    index = "week", 
    columns = "product_group",
    aggfunc = ["mean","std"]
))
# Out:
#                    mean                           std
# product_group     dairy     fruit vegetable     dairy     fruit vegetable
# week
# 44             9.400000  3.233333      2.29  3.535534  1.096966       NaN
# 45             8.233333  2.250000      3.74  2.309401  0.494975  1.060660
# 46             7.900000  3.666667      3.24  2.645751  1.270171  1.767767
# 47             5.900000  2.933333      3.25       NaN  1.270171  0.909945
# 48             6.900000  2.200000      2.29       NaN       NaN       NaN

# %%
display(pd.pivot_table(
    data = grocery, 
    values = "sales_quantity", 
    index = "product_group", 
    columns = "week",
    aggfunc = "sum",
    margins = True,
    margins_name = "Total"
))
# Out:
# week              44     45     46     47    48   Total
# product_group
# dairy           46.0   83.0  130.0   68.0  37.0   364.0
# fruit           99.0   50.0   96.0   74.0  33.0   352.0
# vegetable       29.0   51.0   59.0  162.0   0.0   301.0
# Total          174.0  184.0  285.0  304.0  70.0  1017.0

# %% [markdown]
# ### Задание

# %%
# Необходимо создать сводную таблицу, которая показывает максимальные и минимальные продажи для каждой группы товаров за неделю.

# Инпут:

data = {'product_group': ['fruits', 'vegetables', 'fruits', 'vegetables', 'fruits', 'vegetables'],
        'week': [1, 1, 2, 2, 3, 3],
        'sales_quantity': [20, 15, 25, 12, 30, 18]}

df = pd.DataFrame(data)

                      
                  

# Аутпут:

#                  max         min
# week              1    2    3     1    2    3
# product_group
# fruits           20   25   30    20   25   30
# vegetables       15   12   18    15   12   18

# %%
df
# Out:
#   product_group  week  sales_quantity
# 0        fruits     1              20
# 1    vegetables     1              15
# 2        fruits     2              25
# 3    vegetables     2              12
# 4        fruits     3              30
# 5    vegetables     3              18

# %%
def solution(df):
    result = pd.pivot_table(
        data=df,
        values='sales_quantity',
        index='product_group',
        columns='week',
        aggfunc=['max', 'min']
    )

    return result

# %%
display(solution(df))
# Out:
#               max         min
# week            1   2   3   1   2   3
# product_group
# fruits         20  25  30  20  25  30
# vegetables     15  12  18  15  12  18

# %% [markdown]
# ## Функция where

# %%
grocery = pd.read_csv("grocery.csv")
grocery['price_updated'] = grocery['price'].where(
    grocery['price'] >= 3,
    other = grocery['price'] * 1.1
)

# %%
print("Checking prices less than $3:")
print(grocery[grocery["price"] < 3][["price","price_updated"]].head())

print("\nChecking prices of $3 or more:")
print(grocery[grocery["price"] >= 3][["price","price_updated"]].head())
# Out:
# Checking prices less than $3:
#    price  price_updated
# 0   2.60          2.860
# 1   2.29          2.519
# 3   1.90          2.090
# 4   2.89          3.179
# 5   2.89          3.179
#
# Checking prices of $3 or more:
#     price  price_updated
# 2     6.9            6.9
# 6     4.4            4.4
# 7    10.9           10.9
# 9     5.9            5.9
# 12   10.9           10.9

# %% [markdown]
# ### Задание

# %%
# Используя функцию where, необходимо уменьшить цену на 10% для товаров в категории "vegetables".
# Для всех остальных категорий цены должны остаться неизменными.

# Вход:

data = {'product_group': ['fruits', 'vegetables', 'fruits', 'vegetables', 'fruits'],
        'price': [2.5, 3.5, 2.8, 1.8, 4.0]}

df = pd.DataFrame(data)

                      
                  

# Выход:

#    product_group  price  price_updated
# 0        fruits    2.5            2.50
# 1     vegetables    3.5            3.15
# 2        fruits    2.8            2.80
# 3     vegetables    1.8            1.62
# 4        fruits    4.0            4.00

# %%
def solution(df):
    df['price_updated'] = df['price'].where(
        df['product_group'] != 'vegetables',
        other = df['price'] * 0.9
    )

    return df

# %%
display(solution(df))
# Out:
#   product_group  price  price_updated
# 0        fruits    2.5           2.50
# 1    vegetables    3.5           3.15
# 2        fruits    2.8           2.80
# 3    vegetables    1.8           1.62
# 4        fruits    4.0           4.00

# %% [markdown]
# ## Визуализация

# %%
import matplotlib.pyplot as plt

# %%
grocery = pd.read_csv('grocery.csv')

grocery['price'].plot(kind='hist')

plt.savefig('figs/grocery_price.png')

# %%
grocery['price'].plot(
    kind='hist',
    figsize=(10, 6),
    title='Histogram of grocery prices',
    xticks=range(2, 13)
    )

plt.savefig('figs/grocery_price2.png')

# %%
grocery = grocery.sort_values(
    by="sales_date",
    ascending=True
)

grocery[grocery["product_description"]=="tomato"].plot(
    x = "sales_date", 
    y = ["sales_quantity", 'price'],
    kind = "line",
    figsize = (10,5),
    title = "Daily tomato sales",
    xlabel = "Sales date",
    ylabel = "Sales quantity",
    secondary_y='price' # type: ignore
)

plt.savefig('figs/tomato_sales')

# %%
sales = pd.read_csv("sales.csv")
sales.head()
# Out:
#    product_code product_group  stock_qty    cost    price  last_week_sales  \
# 0          4187           PG2        498  420.76   569.91               13
# 1          4195           PG2        473  545.64   712.41               16
# 2          4204           PG2        968  640.42   854.91               22
# 3          4219           PG2        241  869.69  1034.55               14
# 4          4718           PG2       1401   12.54    26.59               50
#
#    last_month_sales
# 0                58
# 1                58
# 2                88
# 3                45
# 4               285

# %%
sales.plot(
    x='price',
    y='cost',
    kind='scatter',
    figsize=(8, 5),
    title='Cost vs price'
)

plt.savefig('figs/sales')

# %%
sales.plot(
    x='price',
    y='cost',
    kind='scatter',
    figsize=(8, 8),
    title='Cost vs price',
    xlim=(-100, 1000),
    ylim=(-100, 1000),
    grid=True
)

plt.savefig('figs/sales2')

# %% [markdown]
# ## Конкатенация

# %%
df1 = pd.DataFrame({"A":[1,5,3,2], "B":[11,6,9,6], "C":["a","d","f","b"]})

df2 = pd.DataFrame({"A":[2,4,1,7], "B":[14,9,5,8], "C":["b","b","j","a"]})

# %%
df_combined = pd.concat([df1, df2], axis=0)

display(df_combined)
# Out:
#    A   B  C
# 0  1  11  a
# 1  5   6  d
# 2  3   9  f
# 3  2   6  b
# 0  2  14  b
# 1  4   9  b
# 2  1   5  j
# 3  7   8  a

# %%
df1 = pd.DataFrame({"A":[1,5,3,2], "B":[11,6,9,6], "C":["a","d","f","b"]})

df2 = pd.DataFrame({"A":[2,4,1,7], "B":[14,9,5,8], "D":["b","b","j","a"]})

df_combined2 = pd.concat([df1, df2], axis=0, ignore_index=True)

display(df_combined2)
# Out:
#    A   B    C    D
# 0  1  11    a  NaN
# 1  5   6    d  NaN
# 2  3   9    f  NaN
# 3  2   6    b  NaN
# 4  2  14  NaN    b
# 5  4   9  NaN    b
# 6  1   5  NaN    j
# 7  7   8  NaN    a

# %%
df1 = pd.DataFrame({"A":[1,5,3,2], "B":[11,6,9,6], "C":["a","d","f","b"]})

df2 = pd.DataFrame({"A":[2,4,1,7], "B":[14,9,5,8], "D":["b","b","j","a"]})

# %%
df_combined3 = pd.concat([df1, df2], axis=1)

display(df_combined3)
# Out:
#    A   B  C  A   B  D
# 0  1  11  a  2  14  b
# 1  5   6  d  4   9  b
# 2  3   9  f  1   5  j
# 3  2   6  b  7   8  a

# %%
df1 = pd.DataFrame({"A":[1,5,3,2], "B":[11,6,9,6], "C":["a","d","f","b"]})

df2 = pd.DataFrame({"A":[2,4,1,7], "B":[14,9,5,8], "D":["b","b","j","a"]},
                  index=[3,4,5,6])

df_combined = pd.concat([df1, df2], axis=1)

print(df_combined)
# Out:
#      A     B    C    A     B    D
# 0  1.0  11.0    a  NaN   NaN  NaN
# 1  5.0   6.0    d  NaN   NaN  NaN
# 2  3.0   9.0    f  NaN   NaN  NaN
# 3  2.0   6.0    b  2.0  14.0    b
# 4  NaN   NaN  NaN  4.0   9.0    b
# 5  NaN   NaN  NaN  1.0   5.0    j
# 6  NaN   NaN  NaN  7.0   8.0    a

# %% [markdown]
# ### Задание

# %%
# Даны два DataFrame, каждый из которых содержит информацию о студентах и их оценках по разным предметам.
# Объедините их так, чтобы получить один общий DataFrame с оценками всех студентов.
# Используйте параметр ignore_index=True для перенумерации индексов.

# Инпут:

df1 = pd.DataFrame({
    "Name": ["Alice", "Bob"],
    "Math": [85, 78],
    "Science": [92, 88]
}) 

df2 = pd.DataFrame({
    "Name": ["Charlie", "David"],
    "Math": [73, 95],
    "Science": [81, 90]
})



# Аутпут:

pd.DataFrame({
    "Name": ["Alice", "Bob", "Charlie", "David"],
    "Math": [85, 78, 73, 95],
    "Science": [92, 88, 81, 90]
})
# Out:
#       Name  Math  Science
# 0    Alice    85       92
# 1      Bob    78       88
# 2  Charlie    73       81
# 3    David    95       90

# %%
def solution(df1, df2):
    result = pd.concat([df1, df2], axis=0, ignore_index=True)

    return result

# %%
display(solution(df1, df2))
# Out:
#       Name  Math  Science
# 0    Alice    85       92
# 1      Bob    78       88
# 2  Charlie    73       81
# 3    David    95       90

# %% [markdown]
# ## Merge

# %%
# create product and sales DataFrames
product = pd.DataFrame({
  "product_code": [1001, 1002, 1003, 1004],
  "weight": [125, 200, 100, 400],
  "price": [10.5, 24.5, 9.9, 34.5]
})

sales = pd.DataFrame({
  "product_code": [1001, 1002, 1003, 1007],
  "sales_date": ["2021-12-10"] * 4,
  "sales_qty": [8, 14, 22, 7]
})

# %%
merged_df = product.merge(sales, how='left', on='product_code')

display(merged_df)
# Out:
#    product_code  weight  price  sales_date  sales_qty
# 0          1001     125   10.5  2021-12-10        8.0
# 1          1002     200   24.5  2021-12-10       14.0
# 2          1003     100    9.9  2021-12-10       22.0
# 3          1004     400   34.5         NaN        NaN

# %%
merged_df = product.merge(sales, how='inner', on='product_code')

display(merged_df)
# Out:
#    product_code  weight  price  sales_date  sales_qty
# 0          1001     125   10.5  2021-12-10          8
# 1          1002     200   24.5  2021-12-10         14
# 2          1003     100    9.9  2021-12-10         22

# %%
merged_df = product.merge(sales, how='outer', on='product_code')

display(merged_df)
# Out:
#    product_code  weight  price  sales_date  sales_qty
# 0          1001   125.0   10.5  2021-12-10        8.0
# 1          1002   200.0   24.5  2021-12-10       14.0
# 2          1003   100.0    9.9  2021-12-10       22.0
# 3          1004   400.0   34.5         NaN        NaN
# 4          1007     NaN    NaN  2021-12-10        7.0

# %% [markdown]
# # Итоговая проверочная работа

# %% [markdown]
# ## Задача 1

# %%
# Дан DataFrame с информацией о продуктах, содержащий столбцы product, category, и price.
# Необходимо отфильтровать (оставить) все строки, где категория продукта равна 'Electronics', и цена превышает 1000.

# Инпут:

data = {
    'product': ['TV', 'Sofa', 'Laptop', 'Table'],
    'category': ['Electronics', 'Furniture', 'Electronics', 'Furniture'],
    'price': [1200, 800, 1500, 300]
}

df = pd.DataFrame(data)

                      
                  

# Аутпут:

#    product    category  price
# 0       TV  Electronics   1200
# 2   Laptop  Electronics   1500

# %%
def solution(df):
    result = df[(df['category'] == 'Electronics') & (df['price'] > 1000)]

    return result

# %%
display(solution(df))
# Out:
#   product     category  price
# 0      TV  Electronics   1200
# 2  Laptop  Electronics   1500

# %% [markdown]
# ## Задача 2

# %%
# Дан DataFrame, содержащий пропущенные значения в столбце A.
# Необходимо заменить все пропущенные значения в этом столбце на среднее значение столбца A.

# Инпут:

data = {
    'A': [1, 2, np.nan, 4, np.nan],
    'B': [10, 20, 30, 40, 50]
}

df = pd.DataFrame(data)

                      
                  

# Аутпут:

#      A   B
# 0  1.0  10
# 1  2.0  20
# 2  2.333333  30
# 3  4.0  40
# 4  2.333333  50

# %%
def solution(df):
    df['A'] = df['A'].fillna(value=df['A'].mean())
    result = df

    return result

# %%
display(solution(df))
# Out:
#           A   B
# 0  1.000000  10
# 1  2.000000  20
# 2  2.333333  30
# 3  4.000000  40
# 4  2.333333  50

# %% [markdown]
# ## Задача 3

# %%
# Дан DataFrame с датами в столбце date и значениями в столбце sales.
# Необходимо преобразовать столбец date в формат datetime и извлечь месяц в отдельный столбец month.

# Инпут:

data = {
    'date': ['2024-01-15', '2024-02-20', '2024-03-25'],
    'sales': [1000, 1500, 2000]
}

df = pd.DataFrame(data)

                      
                  

# Аутпут:

#         date  sales  month
# 0 2024-01-15   1000      1
# 1 2024-02-20   1500      2
# 2 2024-03-25   2000      3

# %%
def solution(df):
    df = df.astype({
        'date': 'datetime64[ns]'
        })
    
    df['month'] = df['date'].dt.month

    result = df

    return result

# %%
display(solution(df))
# Out:
#         date  sales  month
# 0 2024-01-15   1000      1
# 1 2024-02-20   1500      2
# 2 2024-03-25   2000      3

# %% [markdown]
# ## Задача 4

# %%
# Дан DataFrame с информацией о продажах, содержащий столбцы category и sales.
# Необходимо сгруппировать данные по категории и вычислить общую сумму продаж для каждой категории.

# Инпут:

data = {
    'category': ['Electronics', 'Furniture', 'Electronics', 'Furniture'],
    'sales': [2000, 1500, 3000, 2000]
}

df = pd.DataFrame(data)

                      
                  

# Аутпут:

#     category  sales
# 0  Electronics   5000
# 1   Furniture   3500

                      
                  

# Не забудьте использовать .reset_index() в конце

# %%
def solution(df):
    result = df.groupby('category').agg(sales = ('sales', 'sum')).reset_index()

    return result

# %%
display(solution(df))
# Out:
#       category  sales
# 0  Electronics   5000
# 1    Furniture   3500

# %% [markdown]
# ## Задача 5

# %%
# Дан DataFrame с информацией о студентах, содержащий столбцы student_id, subject, и score.
# Необходимо преобразовать DataFrame, чтобы каждая строка представляла одного студента,
# а каждый предмет был представлен отдельным столбцом с соответствующим баллом.

# Инпут:

data = {
    'student_id': [1, 1, 2, 2],
    'subject': ['Math', 'Science', 'Math', 'Science'],
    'score': [90, 85, 88, 92]
}

df = pd.DataFrame(data)

                      
                  

# Аутпут:

#    student_id  Math  Science
# 0           1    90       85
# 1           2    88       92

                      
                  

# Используйте pivot()

# %%
def solution(df):
    result = pd.pivot(
        data=df,
        values='score',
        columns='subject',
        index='student_id'
    ).reset_index()

    return result

# %%
display(solution(df))
# Out:
# subject  student_id  Math  Science
# 0                 1    90       85
# 1                 2    88       92
